# %% [markdown]
# ### A API e o alembic estão apontados para as variáveis de ambiente, quando definidas
#
# 1 - Adicionar variáveis de ambiente:
#
# Obs: '%40' é URL enconding para '@'
#
# ```bash
# nano ~/.bashrc
# ```
#
# Inserir:
#
# ```bash
# export DATABASE_URL='postgresql://postech-mlengineering:<senha>@localhost:5432/bookstoscrape'
#
# export JWT_SECRET_KEY='Q3rS3+mK9tXvLzH2y0pA4gG8jI1cFo5qE7wB6dRjUeZcXaYwTzQxPvRzWuVsTrQsPnMlJkIh'
# ```
#
# Aplicar:
#
# ```bash
# source ~/.bashrc
# ```
