# %% [markdown]
# 1 - Adicionar variáveis de ambiente:
#
# ```bash
# nano ~/.bashrc
# ```
#
# Inserir:
#
# ```conf
# export DATABASE_URL='postgresql://postech-mlengineering:<senha>@localhost:>
#
# export JWT_SECRET_KEY='Q3rS3+mK9tXvLzH2y0pA4gG8jI1cFo5qE7wB6dRjUeZcXaYwTzQxPvRz>
# ```
#
# Aplicar:
#
# ```bash
# source ~/.bashrc
# ```
