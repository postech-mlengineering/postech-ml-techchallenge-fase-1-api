# %%
import pandas as pd

# %%
df = pd.read_csv('../data/books.csv')
df.head()
# Out:
#                                                title   genre  price  \
# 0                            It's Only the Himalayas  Travel  45.17
# 1  Full Moon over Noahâs Ark: An Odyssey to Mou...  Travel  49.43
# 2  See America: A Celebration of Our National Par...  Travel  48.87
# 3  Vagabonding: An Uncommon Guide to the Art of L...  Travel  36.94
# 4                               Under the Tuscan Sun  Travel  37.33
#
#    availability rating               upc  \
# 0            19    Two  a22124811bfa8350
# 1            15   Four  ce60436f52c5ee68
# 2            14  Three  f9705c362f070608
# 3             8    Two  1809259a5a5f1d8d
# 4             7  Three  a94350ee74deaa07
#
#                                          description  \
# 0  âWherever you go, whatever you do, just . . ...
# 1  Acclaimed travel writer Rick Antonson sets his...
# 2  To coincide with the 2016 centennial anniversa...
# 3  With a new foreword by Tim Ferriss â¢Thereâ...
# ...
